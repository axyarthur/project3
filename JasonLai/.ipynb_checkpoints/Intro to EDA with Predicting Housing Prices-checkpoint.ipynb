# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import gc
from sklearn import svm, grid_search, datasets
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score

# %%
data = pd.read_csv('train.csv', index_col=0)
test = pd.read_csv('test.csv', index_col=0)
all_data = pd.concat([data,test],sort=False)

# %%
all_data.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# Id                                    ...
# 1          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 2          Lvl    AllPub       FR2    ...            0    NaN   NaN
# 3          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 4          Lvl    AllPub    Corner    ...            0    NaN   NaN
# 5          Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#    MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1          NaN       0      2    2008        WD         Normal   208500.0
# 2          NaN       0      5    2007        WD         Normal   181500.0
# 3          NaN       0      9    2008        WD         Normal   223500.0
# 4          NaN       0      2    2006        WD        Abnorml   140000.0
# 5          NaN       0     12    2008        WD         Normal   250000.0
#
# [5 rows x 80 columns]

# %%
column_order = data.columns.tolist()
all_data = all_data[column_order]

# %%
all_data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 7             20       RL         75.0    10084   Pave   NaN      Reg
# 8             60       RL          NaN    10382   Pave   NaN      IR1
# 9             50       RM         51.0     6120   Pave   NaN      Reg
# 10           190       RL         50.0     7420   Pave   NaN      Reg
# 11            20       RL         70.0    11200   Pave   NaN      Reg
# 12            60       RL         85.0    11924   Pave   NaN      IR1
# 13            20       RL          NaN    12968   Pave   NaN      IR2
# 14            20       RL         91.0    10652   Pave   NaN      IR1
# 15            20       RL          NaN    10920   Pave   NaN      IR1
# 16            45       RM         51.0     6120   Pave   NaN      Reg
# 17            20       RL          NaN    11241   Pave   NaN      IR1
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 19            20       RL         66.0    13695   Pave   NaN      Reg
# 20            20       RL         70.0     7560   Pave   NaN      Reg
# 21            60       RL        101.0    14215   Pave   NaN      IR1
# 22            45       RM         57.0     7449   Pave  Grvl      Reg
# 23            20       RL         75.0     9742   Pave   NaN      Reg
# 24           120       RM         44.0     4224   Pave   NaN      Reg
# 25            20       RL          NaN     8246   Pave   NaN      IR1
# 26            20       RL        110.0    14230   Pave   NaN      Reg
# 27            20       RL         60.0     7200   Pave   NaN      Reg
# 28            20       RL         98.0    11478   Pave   NaN      Reg
# 29            20       RL         47.0    16321   Pave   NaN      IR1
# 30            30       RM         60.0     6324   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2890          30       RM         50.0     7030   Pave   NaN      Reg
# 2891          50       RM         75.0     9060   Pave   NaN      Reg
# 2892          30  C (all)         69.0    12366   Pave   NaN      Reg
# 2893         190  C (all)         50.0     9000   Pave   NaN      Reg
# 2894          50  C (all)         60.0     8520   Grvl   NaN      Reg
# 2895         120       RM         41.0     5748   Pave   NaN      IR1
# 2896         120       RM         44.0     3842   Pave   NaN      IR1
# 2897          20       RL         69.0    23580   Pave   NaN      IR1
# 2898          90       RL         65.0     8385   Pave   NaN      Reg
# 2899          20       RL         70.0     9116   Pave   NaN      Reg
# 2900          80       RL        140.0    11080   Pave   NaN      Reg
# 2901          20       RL          NaN    50102   Pave   NaN      IR1
# 2902          20       RL          NaN     8098   Pave   NaN      IR1
# 2903          20       RL         95.0    13618   Pave   NaN      Reg
# 2904          20       RL         88.0    11577   Pave   NaN      Reg
# 2905          20      NaN        125.0    31250   Pave   NaN      Reg
# 2906          90       RM         78.0     7020   Pave   NaN      Reg
# 2907         160       RM         41.0     2665   Pave   NaN      Reg
# 2908          20       RL         58.0    10172   Pave   NaN      IR1
# 2909          90       RL          NaN    11836   Pave   NaN      IR1
# 2910         180       RM         21.0     1470   Pave   NaN      Reg
# 2911         160       RM         21.0     1484   Pave   NaN      Reg
# 2912          20       RL         80.0    13384   Pave   NaN      Reg
# 2913         160       RM         21.0     1533   Pave   NaN      Reg
# 2914         160       RM         21.0     1526   Pave   NaN      Reg
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig    ...     PoolArea PoolQC  Fence  \
# Id                                      ...
# 1            Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2            Lvl    AllPub       FR2    ...            0    NaN    NaN
# 3            Lvl    AllPub    Inside    ...            0    NaN    NaN
# 4            Lvl    AllPub    Corner    ...            0    NaN    NaN
# 5            Lvl    AllPub       FR2    ...            0    NaN    NaN
# 6            Lvl    AllPub    Inside    ...            0    NaN  MnPrv
# 7            Lvl    AllPub    Inside    ...            0    NaN    NaN
# 8            Lvl    AllPub    Corner    ...            0    NaN    NaN
# 9            Lvl    AllPub    Inside    ...            0    NaN    NaN
# 10           Lvl    AllPub    Corner    ...            0    NaN    NaN
# 11           Lvl    AllPub    Inside    ...            0    NaN    NaN
# 12           Lvl    AllPub    Inside    ...            0    NaN    NaN
# 13           Lvl    AllPub    Inside    ...            0    NaN    NaN
# 14           Lvl    AllPub    Inside    ...            0    NaN    NaN
# 15           Lvl    AllPub    Corner    ...            0    NaN   GdWo
# 16           Lvl    AllPub    Corner    ...            0    NaN  GdPrv
# 17           Lvl    AllPub   CulDSac    ...            0    NaN    NaN
# 18           Lvl    AllPub    Inside    ...            0    NaN    NaN
# 19           Lvl    AllPub    Inside    ...            0    NaN    NaN
# 20           Lvl    AllPub    Inside    ...            0    NaN  MnPrv
# 21           Lvl    AllPub    Corner    ...            0    NaN    NaN
# 22           Bnk    AllPub    Inside    ...            0    NaN  GdPrv
# 23           Lvl    AllPub    Inside    ...            0    NaN    NaN
# 24           Lvl    AllPub    Inside    ...            0    NaN    NaN
# 25           Lvl    AllPub    Inside    ...            0    NaN  MnPrv
# 26           Lvl    AllPub    Corner    ...            0    NaN    NaN
# 27           Lvl    AllPub    Corner    ...            0    NaN    NaN
# 28           Lvl    AllPub    Inside    ...            0    NaN    NaN
# 29           Lvl    AllPub   CulDSac    ...            0    NaN    NaN
# 30           Lvl    AllPub    Inside    ...            0    NaN    NaN
# ...          ...       ...       ...    ...          ...    ...    ...
# 2890         Lvl    AllPub    Inside    ...            0    NaN  MnPrv
# 2891         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2892         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2893         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2894         Bnk    AllPub    Inside    ...            0    NaN    NaN
# 2895         HLS    AllPub    Inside    ...            0    NaN    NaN
# 2896         HLS    AllPub    Inside    ...            0    NaN    NaN
# 2897         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2898         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2899         Lvl    AllPub    Corner    ...            0    NaN    NaN
# 2900         Lvl    AllPub    Corner    ...            0    NaN    NaN
# 2901         Low    AllPub    Inside    ...            0    NaN    NaN
# 2902         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2903         Lvl    AllPub    Corner    ...            0    NaN    NaN
# 2904         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2905         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2906         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2907         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2908         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2909         Lvl    AllPub    Corner    ...            0    NaN    NaN
# 2910         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2911         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2912         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2913         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2914         Lvl    AllPub    Inside    ...            0    NaN  GdPrv
# 2915         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2916         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2917         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 2918         Lvl    AllPub    Inside    ...            0    NaN  MnPrv
# 2919         Lvl    AllPub    Inside    ...            0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1            NaN       0      2    2008        WD         Normal   208500.0
# 2            NaN       0      5    2007        WD         Normal   181500.0
# 3            NaN       0      9    2008        WD         Normal   223500.0
# 4            NaN       0      2    2006        WD        Abnorml   140000.0
# 5            NaN       0     12    2008        WD         Normal   250000.0
# 6           Shed     700     10    2009        WD         Normal   143000.0
# 7            NaN       0      8    2007        WD         Normal   307000.0
# 8           Shed     350     11    2009        WD         Normal   200000.0
# 9            NaN       0      4    2008        WD        Abnorml   129900.0
# 10           NaN       0      1    2008        WD         Normal   118000.0
# 11           NaN       0      2    2008        WD         Normal   129500.0
# 12           NaN       0      7    2006       New        Partial   345000.0
# 13           NaN       0      9    2008        WD         Normal   144000.0
# 14           NaN       0      8    2007       New        Partial   279500.0
# 15           NaN       0      5    2008        WD         Normal   157000.0
# 16           NaN       0      7    2007        WD         Normal   132000.0
# 17          Shed     700      3    2010        WD         Normal   149000.0
# 18          Shed     500     10    2006        WD         Normal    90000.0
# 19           NaN       0      6    2008        WD         Normal   159000.0
# 20           NaN       0      5    2009       COD        Abnorml   139000.0
# 21           NaN       0     11    2006       New        Partial   325300.0
# 22           NaN       0      6    2007        WD         Normal   139400.0
# 23           NaN       0      9    2008        WD         Normal   230000.0
# 24           NaN       0      6    2007        WD         Normal   129900.0
# 25           NaN       0      5    2010        WD         Normal   154000.0
# 26           NaN       0      7    2009        WD         Normal   256300.0
# 27           NaN       0      5    2010        WD         Normal   134800.0
# 28           NaN       0      5    2010        WD         Normal   306000.0
# 29           NaN       0     12    2006        WD         Normal   207500.0
# 30           NaN       0      5    2008        WD         Normal    68500.0
# ...          ...     ...    ...     ...       ...            ...        ...
# 2890         NaN       0      3    2006        WD         Normal        NaN
# 2891         NaN       0      4    2006        WD         Normal        NaN
# 2892         NaN       0     10    2006        WD        Abnorml        NaN
# 2893         NaN       0     10    2006        WD        Abnorml        NaN
# 2894         NaN       0      4    2006        WD         Normal        NaN
# 2895         NaN       0      2    2006       New        Partial        NaN
# 2896         NaN       0     12    2006        WD         Normal        NaN
# 2897         NaN       0      9    2006        WD         Normal        NaN
# 2898         NaN       0     10    2006        WD         Normal        NaN
# 2899         NaN       0      5    2006        WD         Normal        NaN
# 2900         NaN       0      5    2006        WD         Normal        NaN
# 2901         NaN       0      3    2006        WD         Alloca        NaN
# 2902         NaN       0     10    2006        WD         Normal        NaN
# 2903         NaN       0     11    2006       New        Partial        NaN
# 2904         NaN       0      9    2006       New        Partial        NaN
# 2905         NaN       0      5    2006        WD         Normal        NaN
# 2906         NaN       0     11    2006        WD         Normal        NaN
# 2907         NaN       0      5    2006        WD         Normal        NaN
# 2908         NaN       0     10    2006        WD         Normal        NaN
# 2909         NaN       0      3    2006        WD         Normal        NaN
# 2910         NaN       0      4    2006        WD         Normal        NaN
# 2911         NaN       0      5    2006        WD         Normal        NaN
# 2912         NaN       0      5    2006        WD         Normal        NaN
# 2913         NaN       0     12    2006        WD        Abnorml        NaN
# 2914         NaN       0      6    2006        WD         Normal        NaN
# 2915         NaN       0      6    2006        WD         Normal        NaN
# 2916         NaN       0      4    2006        WD        Abnorml        NaN
# 2917         NaN       0      9    2006        WD        Abnorml        NaN
# 2918        Shed     700      7    2006        WD         Normal        NaN
# 2919         NaN       0     11    2006        WD         Normal        NaN
#
# [2919 rows x 80 columns]

# %% [markdown]
# # Exploring variables
#
# ### The response variable; SalePrice
#
# The data for the Sale Prices is right skewed, which makes sense because fewer people can afford very expensive houses.

# %%
all_data['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(15,10))
plt.hist(all_data['SalePrice'].dropna(), bins=np.array(range(10000,800000,10000)))
plt.xlabel('SalePrice')
plt.ylabel('Count')
plt.title("Count of each Price")
plt.show()

# %% [markdown]
# ## Important Numeric Predictors
#
# ### Correlations with SalePrice

# %%
all_data.dtypes[all_data.dtypes != 'object']
# Out:
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1       float64
# BsmtFinSF2       float64
# BsmtUnfSF        float64
# TotalBsmtSF      float64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath     float64
# BsmtHalfBath     float64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars       float64
# GarageArea       float64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SalePrice        float64
# dtype: object

# %%
# If the columns data type is int or float
numeric_columns = [col for col in all_data.columns if all_data[col].dtype in ['int64','float64']]

numeric_all_data = all_data[numeric_columns]

# Compute pairwise correlation of columns, excluding NA/null values
all_data_correlation = numeric_all_data.corr()

# %%
all_data_correlation
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.417359 -0.201730     0.033638    -0.065625
# LotFrontage     -0.417359     1.000000  0.489896     0.217645    -0.075508
# LotArea         -0.201730     0.489896  1.000000     0.100541    -0.035617
# OverallQual      0.033638     0.217645  0.100541     1.000000    -0.093847
# OverallCond     -0.065625    -0.075508 -0.035617    -0.093847     1.000000
# YearBuilt        0.034409     0.122811  0.024128     0.597554    -0.368477
# YearRemodAdd     0.043315     0.091557  0.021612     0.571532     0.047654
# MasVnrArea       0.005433     0.221079  0.125596     0.432947    -0.136007
# BsmtFinSF1      -0.064311     0.219408  0.194031     0.281810    -0.050418
# BsmtFinSF2      -0.072530     0.047431  0.084059    -0.042771     0.041501
# BsmtUnfSF       -0.125994     0.113714  0.021362     0.275175    -0.138202
# TotalBsmtSF     -0.219965     0.354822  0.254138     0.549294    -0.174002
# 1stFlrSF        -0.248641     0.458247  0.332460     0.479152    -0.157418
# 2ndFlrSF         0.309309     0.026545  0.031515     0.245596     0.005494
# LowQualFinSF     0.026482     0.004894  0.000554    -0.048393     0.009048
# GrLivArea        0.071677     0.382462  0.284519     0.575126    -0.116569
# BsmtFullBath     0.009950     0.113245  0.128349     0.164543    -0.042133
# BsmtHalfBath    -0.001878    -0.025629  0.026292    -0.040732     0.084181
# FullBath         0.139140     0.181668  0.125826     0.528483    -0.215504
# HalfBath         0.178750     0.039452  0.034244     0.272668    -0.088577
# BedroomAbvGr    -0.008796     0.234892  0.132801     0.073075    -0.008477
# KitchenAbvGr     0.260155     0.004676 -0.020854    -0.159325    -0.086700
# TotRmsAbvGrd     0.040509     0.349513  0.213802     0.389761    -0.092027
# Fireplaces      -0.055151     0.261970  0.261185     0.390753    -0.030999
# GarageYrBlt      0.087898     0.076673 -0.008628     0.571803    -0.325849
# GarageCars      -0.046597     0.310587  0.180434     0.600744    -0.181787
# GarageArea      -0.103394     0.359786  0.213251     0.565122    -0.154149
# WoodDeckSF      -0.017654     0.122070  0.158045     0.255317     0.020123
# OpenPorchSF     -0.015923     0.164896  0.104797     0.298084    -0.068978
# EnclosedPorch   -0.020867     0.011509  0.020974    -0.139256     0.071044
# 3SsnPorch       -0.037529     0.028289  0.015995     0.018715     0.043739
# ScreenPorch     -0.049181     0.075858  0.054375     0.042910     0.043713
# PoolArea        -0.003080     0.174119  0.093708     0.030740    -0.016876
# MiscVal         -0.028867     0.044272  0.069029     0.005562     0.033956
# MoSold          -0.001231     0.011254  0.004156     0.030405    -0.006256
# YrSold          -0.015028    -0.007917 -0.024234    -0.019614     0.030102
# SalePrice       -0.084284     0.351799  0.263843     0.790982    -0.077856
#
#                YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# MSSubClass      0.034409      0.043315    0.005433   -0.064311   -0.072530
# LotFrontage     0.122811      0.091557    0.221079    0.219408    0.047431
# LotArea         0.024128      0.021612    0.125596    0.194031    0.084059
# OverallQual     0.597554      0.571532    0.432947    0.281810   -0.042771
# OverallCond    -0.368477      0.047654   -0.136007   -0.050418    0.041501
# YearBuilt       1.000000      0.612235    0.314051    0.279581   -0.027595
# YearRemodAdd    0.612235      1.000000    0.196875    0.152126   -0.062153
# MasVnrArea      0.314051      0.196875    1.000000    0.303490   -0.015645
# BsmtFinSF1      0.279581      0.152126    0.303490    1.000000   -0.055045
# BsmtFinSF2     -0.027595     -0.062153   -0.015645   -0.055045    1.000000
# BsmtUnfSF       0.130473      0.165175    0.090163   -0.477404   -0.238241
# TotalBsmtSF     0.408515      0.298107    0.397240    0.536467    0.089410
# 1stFlrSF        0.310814      0.242245    0.395834    0.458092    0.084330
# 2ndFlrSF        0.017588      0.158985    0.121014   -0.162301   -0.097744
# LowQualFinSF   -0.144191     -0.060371   -0.057912   -0.066028   -0.004923
# GrLivArea       0.242666      0.316972    0.402994    0.211669   -0.017872
# BsmtFullBath    0.211580      0.134947    0.141593    0.638847    0.162835
# BsmtHalfBath   -0.030282     -0.046285    0.015006    0.078361    0.099485
# FullBath        0.471169      0.457980    0.259777    0.081525   -0.075432
# HalfBath        0.269743      0.211430    0.191950   -0.007311   -0.032448
# BedroomAbvGr   -0.053101     -0.021912    0.078126   -0.113547   -0.031223
# KitchenAbvGr   -0.137614     -0.142431   -0.051389   -0.086354   -0.037779
# TotRmsAbvGrd    0.114280      0.198250    0.278228    0.052141   -0.048423
# Fireplaces      0.170680      0.134157    0.275195    0.293089    0.065625
# GarageYrBlt     0.834812      0.652365    0.255112    0.194270   -0.068549
# GarageCars      0.538074      0.426022    0.361190    0.255482   -0.014827
# GarageArea      0.480735      0.376765    0.374061    0.310449    0.003139
# WoodDeckSF      0.229426      0.218513    0.166200    0.223492    0.098399
# OpenPorchSF     0.198554      0.242182    0.144650    0.124163   -0.005876
# EnclosedPorch  -0.374073     -0.220456   -0.111499   -0.099712    0.032740
# 3SsnPorch       0.015958      0.037433    0.013612    0.050908   -0.023279
# ScreenPorch    -0.041046     -0.046878    0.065209    0.096823    0.063302
# PoolArea        0.002304     -0.011407    0.004512    0.084462    0.044524
# MiscVal        -0.010886     -0.003124    0.044811    0.093295   -0.005139
# MoSold          0.013938      0.017693   -0.000117   -0.000942   -0.009593
# YrSold         -0.012344      0.033203   -0.018510    0.022556    0.008883
# SalePrice       0.522897      0.507101    0.477493    0.386420   -0.011378
#
#                  ...      WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# MSSubClass       ...       -0.017654    -0.015923      -0.020867  -0.037529
# LotFrontage      ...        0.122070     0.164896       0.011509   0.028289
# LotArea          ...        0.158045     0.104797       0.020974   0.015995
# OverallQual      ...        0.255317     0.298084      -0.139256   0.018715
# OverallCond      ...        0.020123    -0.068978       0.071044   0.043739
# YearBuilt        ...        0.229426     0.198554      -0.374073   0.015958
# YearRemodAdd     ...        0.218513     0.242182      -0.220456   0.037433
# MasVnrArea       ...        0.166200     0.144650      -0.111499   0.013612
# BsmtFinSF1       ...        0.223492     0.124163      -0.099712   0.050908
# BsmtFinSF2       ...        0.098399    -0.005876       0.032740  -0.023279
# BsmtUnfSF        ...       -0.039302     0.119764       0.005006  -0.005810
# TotalBsmtSF      ...        0.229600     0.245521      -0.085510   0.037892
# 1stFlrSF         ...        0.227347     0.238502      -0.065796   0.044086
# 2ndFlrSF         ...        0.089922     0.185387       0.054645  -0.032458
# LowQualFinSF     ...       -0.015622    -0.000692       0.087212  -0.004545
# GrLivArea        ...        0.251017     0.341907       0.003274   0.006268
# BsmtFullBath     ...        0.186107     0.081265      -0.068393   0.027378
# BsmtHalfBath     ...        0.051549    -0.034917      -0.009675   0.026861
# FullBath         ...        0.181266     0.260423      -0.118983   0.015192
# HalfBath         ...        0.116701     0.182048      -0.081978  -0.023417
# BedroomAbvGr     ...        0.031644     0.086212       0.049940  -0.048279
# KitchenAbvGr     ...       -0.087399    -0.068181       0.027639  -0.021462
# TotRmsAbvGrd     ...        0.156543     0.238156       0.015345  -0.025764
# Fireplaces       ...        0.227608     0.158621       0.000971   0.018852
# GarageYrBlt      ...        0.222584     0.231639      -0.300751   0.020699
# GarageCars       ...        0.240715     0.203544      -0.132846   0.023383
# GarageArea       ...        0.238075     0.232559      -0.106417   0.029440
# WoodDeckSF       ...        1.000000     0.038457      -0.119114  -0.003935
# OpenPorchSF      ...        0.038457     1.000000      -0.059672  -0.009392
# EnclosedPorch    ...       -0.119114    -0.059672       1.000000  -0.032822
# 3SsnPorch        ...       -0.003935    -0.009392      -0.032822   1.000000
# ScreenPorch      ...       -0.052134     0.047777      -0.064377  -0.029546
# PoolArea         ...        0.094231     0.064212       0.092534  -0.006525
# MiscVal          ...        0.056883     0.077357       0.008654  -0.000788
# MoSold           ...        0.018120     0.034167      -0.020976   0.027391
# YrSold           ...       -0.000180    -0.037377      -0.001134   0.022560
# SalePrice        ...        0.324413     0.315856      -0.128578   0.044584
#
#                ScreenPorch  PoolArea   MiscVal    MoSold    YrSold  SalePrice
# MSSubClass       -0.049181 -0.003080 -0.028867 -0.001231 -0.015028  -0.084284
# LotFrontage       0.075858  0.174119  0.044272  0.011254 -0.007917   0.351799
# LotArea           0.054375  0.093708  0.069029  0.004156 -0.024234   0.263843
# OverallQual       0.042910  0.030740  0.005562  0.030405 -0.019614   0.790982
# OverallCond       0.043713 -0.016876  0.033956 -0.006256  0.030102  -0.077856
# YearBuilt        -0.041046  0.002304 -0.010886  0.013938 -0.012344   0.522897
# YearRemodAdd     -0.046878 -0.011407 -0.003124  0.017693  0.033203   0.507101
# MasVnrArea        0.065209  0.004512  0.044811 -0.000117 -0.018510   0.477493
# BsmtFinSF1        0.096823  0.084462  0.093295 -0.000942  0.022556   0.386420
# BsmtFinSF2        0.063302  0.044524 -0.005139 -0.009593  0.008883  -0.011378
# BsmtUnfSF        -0.049158 -0.032273 -0.010492  0.022607 -0.038015   0.214479
# TotalBsmtSF       0.075363  0.072216  0.084002  0.017888 -0.011184   0.613581
# 1stFlrSF          0.098381  0.121900  0.093062  0.040143 -0.013442   0.605852
# 2ndFlrSF          0.011070  0.044503 -0.005299  0.014185 -0.019229   0.319334
# LowQualFinSF      0.006835  0.035177 -0.005973  0.011528 -0.002257  -0.025606
# GrLivArea         0.086284  0.135441  0.067118  0.044198 -0.026919   0.708624
# BsmtFullBath      0.053119  0.043970 -0.004629 -0.003568  0.045255   0.227122
# BsmtHalfBath      0.042069  0.066851  0.036902  0.023014 -0.020028  -0.016844
# FullBath         -0.015910  0.028091 -0.010024  0.046274 -0.004882   0.560664
# HalfBath          0.035622  0.001424  0.026553 -0.001136  0.001587   0.284108
# BedroomAbvGr      0.007254  0.036544  0.000245  0.055997 -0.020453   0.168213
# KitchenAbvGr     -0.056573 -0.013116  0.025078  0.035493  0.035173  -0.135907
# TotRmsAbvGrd      0.032324  0.072061  0.060903  0.045137 -0.032354   0.533723
# Fireplaces        0.169784  0.099123  0.008535  0.032352 -0.006752   0.466929
# GarageYrBlt      -0.062320 -0.014467 -0.009203  0.024017 -0.004543   0.486362
# GarageCars        0.043112  0.030424 -0.016934  0.050882 -0.022918   0.640409
# GarageArea        0.062389  0.053049  0.008446  0.040335 -0.013451   0.623431
# WoodDeckSF       -0.052134  0.094231  0.056883  0.018120 -0.000180   0.324413
# OpenPorchSF       0.047777  0.064212  0.077357  0.034167 -0.037377   0.315856
# EnclosedPorch    -0.064377  0.092534  0.008654 -0.020976 -0.001134  -0.128578
# 3SsnPorch        -0.029546 -0.006525 -0.000788  0.027391  0.022560   0.044584
# ScreenPorch       1.000000  0.026319  0.007067  0.028535 -0.006634   0.111447
# PoolArea          0.026319  1.000000  0.011921 -0.042230 -0.052816   0.092404
# MiscVal           0.007067  0.011921  1.000000  0.007443  0.008445  -0.021190
# MoSold            0.028535 -0.042230  0.007443  1.000000 -0.153895   0.046432
# YrSold           -0.006634 -0.052816  0.008445 -0.153895  1.000000  -0.028923
# SalePrice         0.111447  0.092404 -0.021190  0.046432 -0.028923   1.000000
#
# [37 rows x 37 columns]

# %%
# Get columns with a abs(correlation) of at least .5

# Take the absolute value of the correlations in the last column (SalePrice), Sort by descending values
high_corr_columns = all_data_correlation.iloc[:,36].abs().sort_values(ascending=False)

# Take only Correlations with greater than or equal to .5
# Reset the index to get column names written in column 0 instead of as the index
# Take only column 0 (column names), and make it a list
high_corr_columns = high_corr_columns[high_corr_columns >= .5].reset_index().iloc[:,0].tolist()
high_corr_columns
# Out:
# ['SalePrice',
#  'OverallQual',
#  'GrLivArea',
#  'GarageCars',
#  'GarageArea',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'YearBuilt',
#  'YearRemodAdd']

# %%
plt.figure(figsize=(15,10))
sns.heatmap(numeric_all_data[high_corr_columns].corr(),annot=True)
plt.show()

# %%
all_data_correlation = None
del all_data_correlation
numeric_all_data = None
del numeric_all_data

# %% [markdown]
# ### Overall Quality
# - Has the highest correlation with SalePrice among the numeric variables (0.79)
# - OverallQual: Rates the overall material and finish of the house
#
#        10	Very Excellent
#        9	Excellent
#        8	Very Good
#        7	Good
#        6	Above Average
#        5	Average
#        4	Below Average
#        3	Fair
#        2	Poor
#        1	Very Poor

# %%
overallQual_pivot = all_data[['OverallQual','SalePrice']].pivot_table(values='SalePrice',index=all_data.index,columns='OverallQual').describe()
overallQual_pivot
# Out:
# OverallQual            1             2              3              4   \
# count            2.000000      3.000000      20.000000     116.000000
# mean         50150.000000  51770.333333   87473.750000  108420.655172
# std          15344.217152  14254.200796   24688.567399   29022.003886
# min          39300.000000  35311.000000   37900.000000   34900.000000
# 25%          44725.000000  47655.500000   75500.000000   88000.000000
# 50%          50150.000000  60000.000000   86250.000000  108000.000000
# 75%          55575.000000  60000.000000   97500.000000  125500.000000
# max          61000.000000  60000.000000  139600.000000  256000.000000
#
# OverallQual             5              6              7              8   \
# count           397.000000     374.000000     319.000000     168.000000
# mean         133523.347607  161603.034759  207716.423197  274735.535714
# std           27107.330927   36090.182933   44466.259414   63898.902253
# min           55993.000000   76000.000000   82500.000000  122000.000000
# 25%          118000.000000  139125.000000  179470.000000  234557.500000
# 50%          133000.000000  160000.000000  200141.000000  269750.000000
# 75%          147000.000000  181000.000000  230750.000000  306250.000000
# max          228950.000000  277000.000000  383970.000000  538000.000000
#
# OverallQual             9              10
# count            43.000000      18.000000
# mean         367513.023256  438588.388889
# std           81278.174849  159785.491058
# min          239000.000000  160000.000000
# 25%          318980.500000  349375.000000
# 50%          345000.000000  432390.000000
# 75%          389716.000000  472875.000000
# max          611657.000000  755000.000000

# %%
overallQual_pivot.plot(kind='box',figsize=(15,10))
plt.annotate(str(overallQual_pivot[overallQual_pivot[4] == overallQual_pivot[4].max()].index[0]),
             xy=(4,overallQual_pivot[4].max()),xytext=(4,overallQual_pivot[4].max()+10000))
plt.xlabel('Overall Quality')
plt.ylabel('Sale Price')
plt.title('OverallQual v SalePrice')
plt.show()

# %% [markdown]
# The positive correlation between Overall Quality and Sale Price is definitely there.  There seems to be a possible outlier at the max value of quality level 4. It looks like an overly expensive house for a quality level of 4.

# %%
overallQual_pivot= None
del overallQual_pivot

# %% [markdown]
# ### Above Grade Living Area
# - GrLivArea: Above grade (ground) living area in square feet
# - Has the second highest correlation with SalePrice among the numeric vatiables (0.71)
#     - This makes sense, Big houses generally cost more!

# %%
plt.figure(figsize=(15,10))
plt.scatter(all_data['GrLivArea'], all_data['SalePrice'])
#########
# Annotate the indexes onto the two outlier points
#########
plt.xlabel('Above Ground Living Area (sqft)')
plt.ylabel('Sale Price')
plt.title('Above Ground Living Area v Sale Price')
plt.show()

# %%
sns.jointplot(x='GrLivArea',y='SalePrice',data=all_data,
              kind="reg", xlim=(0, 6000),ylim=(0,800000),height=8)

# %% [markdown]
# The two houses with large above ground living area for low costs (the bottom right of the image) seem like outliers as well.  Though they seem like outliers, I feel it smarter to leave them in because there could be other factors associated.  For instance, a low score on the Overall Quality could explain a low price.  However, as you can see below, these two houses actually also score a 10 on the Overall Quality.  Therefore, I will keep them in mind when looking at other variables to see if they are truly outliers, or if there is an explanation for the low Sale Price.

# %%
all_data.loc[all_data['GrLivArea']>4500] #2550 is a 'test' house
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 524           60       RL        130.0    40094   Pave   NaN      IR1
# 1299          60       RL        313.0    63887   Pave   NaN      IR3
# 2550          20       RL        128.0    39290   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# Id                                      ...
# 524          Bnk    AllPub    Inside    ...            0    NaN   NaN
# 1299         Bnk    AllPub    Corner    ...          480     Gd   NaN
# 2550         Bnk    AllPub    Inside    ...            0    NaN   NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 524          NaN       0     10    2007       New        Partial   184750.0
# 1299         NaN       0      1    2008       New        Partial   160000.0
# 2550         NaN   17000     10    2007       New        Partial        NaN
#
# [3 rows x 80 columns]

# %%
all_data.loc[(524,1299),['SalePrice','GrLivArea','OverallQual']]
# Out:
#       SalePrice  GrLivArea  OverallQual
# Id
# 524    184750.0       4676           10
# 1299   160000.0       5642           10

# %% [markdown]
# # Missing data, label encoding, and factorizing variables
#
# ### Completeness of the data
#
# First, I'm going to check to see which variables contain missing values

# %%
NAcol = all_data.isnull().sum().sort_values(ascending=False)
print("There are "+str(len(NAcol[NAcol > 0]))+" columns with missing values:")
print(NAcol[NAcol > 0])
# Out:
# There are 35 columns with missing values:
# PoolQC          2909
# MiscFeature     2814
# Alley           2721
# Fence           2348
# SalePrice       1459
# FireplaceQu     1420
# LotFrontage      486
# GarageCond       159
# GarageYrBlt      159
# GarageQual       159
# GarageFinish     159
# GarageType       157
# BsmtCond          82
# BsmtExposure      82
# BsmtQual          81
# BsmtFinType2      80
# BsmtFinType1      79
# MasVnrType        24
# MasVnrArea        23
# MSZoning           4
# Utilities          2
# Functional         2
# BsmtFullBath       2
# BsmtHalfBath       2
# GarageCars         1
# BsmtFinSF2         1
# Exterior2nd        1
# GarageArea         1
# TotalBsmtSF        1
# BsmtUnfSF          1
# BsmtFinSF1         1
# Exterior1st        1
# KitchenQual        1
# SaleType           1
# Electrical         1
# dtype: int64

# %% [markdown]
# As shown by the below 2 commands, the 1459 Na SalePrice values are the values from the test.csv dataset.

# %%
test.head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig      ...       ScreenPorch PoolArea  \
# Id                                        ...
# 1461         Lvl    AllPub    Inside      ...               120        0
# 1462         Lvl    AllPub    Corner      ...                 0        0
# 1463         Lvl    AllPub    Inside      ...                 0        0
# 1464         Lvl    AllPub    Inside      ...                 0        0
# 1465         HLS    AllPub    Inside      ...               144        0
#
#      PoolQC  Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  \
# Id
# 1461    NaN  MnPrv         NaN       0       6    2010        WD
# 1462    NaN    NaN        Gar2   12500       6    2010        WD
# 1463    NaN  MnPrv         NaN       0       3    2010        WD
# 1464    NaN    NaN         NaN       0       6    2010        WD
# 1465    NaN    NaN         NaN       0       1    2010        WD
#
#       SaleCondition
# Id
# 1461         Normal
# 1462         Normal
# 1463         Normal
# 1464         Normal
# 1465         Normal
#
# [5 rows x 79 columns]

# %%
all_data[all_data['SalePrice'].isnull()].head()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1462          20       RL         81.0    14267   Pave   NaN      IR1
# 1463          60       RL         74.0    13830   Pave   NaN      IR1
# 1464          60       RL         78.0     9978   Pave   NaN      IR1
# 1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig    ...     PoolArea PoolQC  Fence  \
# Id                                      ...
# 1461         Lvl    AllPub    Inside    ...            0    NaN  MnPrv
# 1462         Lvl    AllPub    Corner    ...            0    NaN    NaN
# 1463         Lvl    AllPub    Inside    ...            0    NaN  MnPrv
# 1464         Lvl    AllPub    Inside    ...            0    NaN    NaN
# 1465         HLS    AllPub    Inside    ...            0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# 1461         NaN       0      6    2010        WD         Normal        NaN
# 1462        Gar2   12500      6    2010        WD         Normal        NaN
# 1463         NaN       0      3    2010        WD         Normal        NaN
# 1464         NaN       0      6    2010        WD         Normal        NaN
# 1465         NaN       0      1    2010        WD         Normal        NaN
#
# [5 rows x 80 columns]

# %% [markdown]
# ### Imputing missing data
#
#
# **######################### Pool Variables ############################**
#
# - PoolArea: Pool area in square feet
# - PoolQC: Pool quality
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        NA	No Pool

# %%
# If no pool recorded, assume None
all_data['PoolQC'].fillna('None', inplace=True)

# %%
Qualities = {'None':0,'Po':1,'Fa':2,'TA':3,'Gd':4,'Ex':5}

# %%
all_data['PoolQC'] = all_data['PoolQC'].map(Qualities)

# %%
all_data['PoolQC'].value_counts()
# Out:
# 0    2909
# 5       4
# 4       4
# 2       2
# Name: PoolQC, dtype: int64

# %%
# Check for any pools assumed no pool, that have a poolArea listed.
all_data[(all_data['PoolQC']==0)&(all_data['PoolArea']>0)][['PoolArea','PoolQC']]
# Out:
#       PoolArea  PoolQC
# Id
# 2421       368       0
# 2504       444       0
# 2600       561       0

# %%
plt.figure(figsize=(15,10))
plt.scatter(all_data['PoolArea'],all_data['PoolQC'])
plt.xlabel('Pool Area')
plt.ylabel('Pool Quality')
plt.title('Pool Area v Pool Quality')
plt.show()

# %% [markdown]
# No clear correlation between pool size and pool quality.

# %%
# Correlation between Pool Quality that is greater than 0 and Overall Quality
all_data[(all_data['PoolQC']>0)][['PoolQC','OverallQual']].corr()
# Out:
#                PoolQC  OverallQual
# PoolQC       1.000000     0.570544
# OverallQual  0.570544     1.000000

# %%
plt.figure(figsize=(15,10))
plt.scatter(all_data[(all_data['PoolQC']>0)]['OverallQual'],all_data[(all_data['PoolQC']>0)]['PoolQC'])
plt.xlabel('Overall Quality')
plt.ylabel('Pool Quality')
plt.title('Overall Quality v Pool Quality')
plt.yticks(np.arange(0,6,step=1))
plt.xticks(np.arange(0,11,step=1))
plt.show()

# %%
all_data[(all_data['PoolQC']==0)&(all_data['PoolArea']>0)][['PoolArea','PoolQC','OverallQual']]
# Out:
#       PoolArea  PoolQC  OverallQual
# Id
# 2421       368       0            4
# 2504       444       0            6
# 2600       561       0            3

# %%
all_data.loc[(all_data['PoolQC']!=0)&(all_data['PoolArea']>0),['OverallQual','PoolQC']].groupby('OverallQual').describe()
# Out:
#             PoolQC
#              count      mean       std  min  25%  50%  75%  max
# OverallQual
# 6              3.0  3.333333  1.154701  2.0  3.0  4.0  4.0  4.0
# 7              2.0  3.000000  1.414214  2.0  2.5  3.0  3.5  4.0
# 8              2.0  5.000000  0.000000  5.0  5.0  5.0  5.0  5.0
# 10             3.0  4.666667  0.577350  4.0  4.5  5.0  5.0  5.0

# %% [markdown]
# Using the mean value for PoolQC per OverallQual

# %%
all_data.loc[2421,'PoolQC'] = 2
all_data.loc[2504,'PoolQC'] = 3
all_data.loc[2600,'PoolQC'] = 2

# %% [markdown]
# **######################### ^Pool Variables^ ############################**
#
# **######################### Misc Features ############################**
#
# - MiscFeature: Miscellaneous feature not covered in other categories
#
#        Elev	Elevator
#        Gar2	2nd Garage (if not described in garage section)
#        Othr	Other
#        Shed	Shed (over 100 SF)
#        TenC	Tennis Court
#        NA	None

# %%
all_data.MiscFeature.fillna('None',inplace=True)
all_data['MiscFeature'] = all_data.MiscFeature.astype('category')

# %%
all_data['MiscFeature'].value_counts()
# Out:
# None    2814
# Shed      95
# Gar2       5
# Othr       4
# TenC       1
# Name: MiscFeature, dtype: int64

# %%
miscFeature_pivot = all_data[['MiscFeature','SalePrice']].pivot_table(values='SalePrice',index=all_data.index , columns='MiscFeature')

# %% [markdown]
# Look at the median house price by feature

# %%
plt.figure(figsize=(15,10))
miscFeature_pivot.median().plot(kind='bar', width=.8)
plt.ylabel('SalePrice')
plt.xlabel('MiscFeature')
plt.title('Median Sale Price of each Feature')

# Add the counts of each feature, in white, to bottom of bar
for i in range(0,5):
    plt.text(i,9000,str(miscFeature_pivot.count()[i]), fontsize=15, color= 'white')
plt.show()

# %%
miscFeature_pivot = None
del miscFeature_pivot

# %% [markdown]
# **######################### ^Misc Features^ ############################**
#
# **#########################     Alley     ############################**
#
# - Alley: Type of alley access to property
#
#        Grvl	Gravel
#        Pave	Paved
#        NA 	No alley access

# %%
all_data['Alley'].fillna('None',inplace=True)
all_data['Alley'] = all_data['Alley'].astype('category')

# %% [markdown]
# **######################### ^Alley^ ############################**
#
# **#########################     Fence     ############################**
#
# Fence: Fence quality
#
#        GdPrv	Good Privacy
#        MnPrv	Minimum Privacy
#        GdWo	Good Wood
#        MnWw	Minimum Wood/Wire
#        NA	No Fence

# %%
all_data.Fence.fillna("None", inplace=True)
all_data['Fence'].value_counts()
# Out:
# None     2348
# MnPrv     329
# GdPrv     118
# GdWo      112
# MnWw       12
# Name: Fence, dtype: int64

# %%
median_fence = all_data.pivot_table(values='SalePrice',index=all_data.index,columns='Fence')

# %%
plt.figure(figsize=(15,10))
median_fence.median().plot(kind='bar',width=.8)
plt.xlabel('Fence')
plt.ylabel('SalePrice')
plt.title('Fence type v median Sale Price')
#plt.show()

# Add the counts of each feature, in white, to bottom of bar
for i in range(0,5):
    plt.text(i,9000,str(median_fence.count()[i]), fontsize=15, color= 'white')
plt.show()

# %%
median_fence = None
del median_fence

# %%
all_data['Fence'] = all_data['Fence'].astype('category')

# %% [markdown]
# **######################### ^Fence^ ############################**
#
# **#########################     Fireplace     ############################**
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace

# %%
all_data['FireplaceQu'].fillna('None',inplace=True)

print(all_data['Fireplaces'].value_counts())
print(all_data['FireplaceQu'].value_counts())
# Out:
# 0    1420
# 1    1268
# 2     219
# 3      11
# 4       1
# Name: Fireplaces, dtype: int64
# None    1420
# Gd       744
# TA       592
# Fa        74
# Po        46
# Ex        43
# Name: FireplaceQu, dtype: int64

# %% [markdown]
# The number of homes with '0' fireplaces matches the number of fireplace Qualities equaling nan

# %%
all_data['FireplaceQu'] = all_data['FireplaceQu'].map(Qualities)

# %% [markdown]
# **Lot Variables:**
# - LotFrontage: Linear feet of street connected to property
# - LotArea: Lot size in square feet
# - LotShape: General shape of property
#
#        Reg	Regular
#        IR1	Slightly irregular
#        IR2	Moderately Irregular
#        IR3	Irregular
# - LotConfig: Lot configuration
#
#        Inside	Inside lot
#        Corner	Corner lot
#        CulDSac	Cul-de-sac
#        FR2	Frontage on 2 sides of property
#        FR3	Frontage on 3 sides of property

# %%
median_lotfrontage = all_data.pivot_table(values='LotFrontage',index=all_data.index,columns='Neighborhood')

# %%
plt.figure(figsize=(15,10))
median_lotfrontage.median().plot(kind='bar',width=.8)
plt.ylabel("LotFrontage")
plt.xlabel("Neighborhood")
plt.show()

# %% [markdown]
# Going to Impute the Lot Frontage values from the Neighborhoods average value.

# %%
for i in range(1,len(all_data)):
    if (np.isnan(all_data.loc[i,'LotFrontage'])):
        all_data.loc[i,'LotFrontage'] = \
        int(median_lotfrontage.median()[str(all_data.loc[i,'Neighborhood'])])

# %%
median_lotfrontage = None
del median_lotfrontage

# %%
median_lotshape = all_data.pivot_table(values='SalePrice',index=all_data.index,columns='LotShape').describe()

median_lotshape.plot(kind='box', figsize=(15,10))
plt.ylabel("SalePrice")
plt.xlabel("LotShape")
plt.show()

# %%
median_lotshape = None
del median_lotshape

# %%
all_data['LotShape'] = all_data['LotShape'].map({'IR3':0, 'IR2':1, 'IR1':2, 'Reg':3})

# %%
median_lotconfig = all_data.pivot_table(values='SalePrice',columns='LotConfig')

median_lotconfig.mean().sort_values().plot(kind='bar',figsize=(15,10), width=.8)
plt.xlabel('LotConfig')
plt.ylabel('SalePrice')
plt.show()

plt.figure(figsize=(15,10))
sns.swarmplot(x='LotConfig',y='SalePrice',data=all_data,order=['Inside','FR2','Corner','FR3','CulDSac'])
plt.show()

# %% [markdown]
# There doesn't seem to be any order to the Lot Config variables, it will also be treated as type Category.

# %%
median_lotconfig = None
del median_lotconfig

# %%
all_data['LotConfig'] = all_data['LotConfig'].astype('category')

# %% [markdown]
# **Garage Variables:**
# - GarageType: Garage location (157 NA)
#
#        2Types	More than one type of garage
#        Attchd	Attached to home
#        Basment	Basement Garage
#        BuiltIn	Built-In (Garage part of house - typically has room above garage)
#        CarPort	Car Port
#        Detchd	Detached from home
#        NA	No Garage
#
# - GarageYrBlt: Year garage was built (159 NA)
#
# - GarageFinish: Interior finish of the garage (159 NA)
#
#        Fin	Finished
#        RFn	Rough Finished
#        Unf	Unfinished
#        NA	No Garage
#
# - GarageCars: Size of garage in car capacity (1 NA)
#
# - GarageArea: Size of garage in square feet (1 NA)
#
# - GarageQual: Garage quality (159 NA)
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage
#
# - GarageCond: Garage condition (159 NA)
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor
#        NA	No Garage

# %% [markdown]
# Making GarageYrBlt = year the house was built

# %%
all_data.loc[all_data['GarageYrBlt'].isnull(),'GarageYrBlt'] = all_data.loc[all_data['GarageYrBlt'].isnull(),'YearBuilt']

# %%
# Checking if the 157 NA in Garage Type are the same NAs within the
#   other variables with 159 NAs

len(all_data[(all_data['GarageType'].isnull())&\
             (all_data['GarageFinish'].isnull())&\
             (all_data['GarageCond'].isnull())&\
             (all_data['GarageQual'].isnull())])
# Out:
# 157

# %%
# The other 2 rows with NAs in a Garage variable
all_data[(~all_data['GarageType'].isnull())&\
         (all_data['GarageFinish'].isnull())&\
         (all_data['GarageCond'].isnull())&\
         (all_data['GarageQual'].isnull())]\
[['GarageCars', 'GarageArea', 'GarageType',
  'GarageCond', 'GarageQual', 'GarageFinish']]
# Out:
#       GarageCars  GarageArea GarageType GarageCond GarageQual GarageFinish
# Id
# 2127         1.0       360.0     Detchd        NaN        NaN          NaN
# 2577         NaN         NaN     Detchd        NaN        NaN          NaN

# %%
all_data.loc[2127,'GarageFinish'] = all_data['GarageFinish'].mode()[0]
all_data.loc[2127,'GarageCond'] = all_data['GarageCond'].mode()[0]
all_data.loc[2127,'GarageQual'] = all_data['GarageQual'].mode()[0]

# %%
all_data.loc[2577,'GarageCars'] = 0
all_data.loc[2577,'GarageArea'] = 0
all_data.loc[2577,'GarageType'] = np.nan

# %%
len(all_data[(all_data['GarageType'].isnull())&\
             (all_data['GarageFinish'].isnull())&\
             (all_data['GarageCond'].isnull())&\
             (all_data['GarageQual'].isnull())])
# Out:
# 158

# %% [markdown]
# Now the 4 chatacter variables related to garage all have the same set of 158 NAs.  Which correspond to: "No Garage".
#
# GarageType does not seem to be Ordinal, so we will use it as a categorical variable.

# %%
all_data['GarageType'].fillna('No Garage', inplace = True)

# %%
plt.figure(figsize=(15,10))
sns.swarmplot(x='GarageType',y='SalePrice',
              data=all_data, 
              order=['No Garage','CarPort','Detchd',
                     '2Types','Basment','Attchd','BuiltIn'
                    ]
             )
plt.show()

# %%
all_data['GarageType'] = all_data['GarageType'].astype('category')

# %% [markdown]
# The values of GarageFinish seem to be ordinal

# %%
all_data['GarageFinish'].fillna('None', inplace=True)
FinishQual = {'None':0, 'Unf':1, 'RFn':2, 'Fin':3}

all_data['GarageFinish'] = all_data['GarageFinish'].map(FinishQual)

FinishQual = None
del FinishQual

# %% [markdown]
# GarageQual is another variable that is ordinal

# %%
all_data['GarageQual'].fillna('None',inplace=True)
all_data['GarageQual'] = all_data['GarageQual'].map(Qualities)

# %%
all_data['GarageCond'].fillna('None',inplace=True)
all_data['GarageCond'] = all_data['GarageCond'].map(Qualities)

# %% [markdown]
# **Basement Variables:**
# - BsmtFinSF1: Type 1 finished square feet
# - BsmtFinSF2: Type 2 finished square feet
# - BsmtUnfSF: Unfinished square feet of basement area
# - TotalBsmtSF: Total square feet of basement area
# - BsmtFullBath: Basement full bathrooms
# - BsmtHalfBath: Basement half bathrooms
# - BsmtQual: Evaluates the height of the basement
#
#        Ex	Excellent (100+ inches)
#        Gd	Good (90-99 inches)
#        TA	Typical (80-89 inches)
#        Fa	Fair (70-79 inches)
#        Po	Poor (<70 inches
#        NA	No Basement
#
# - BsmtCond: Evaluates the general condition of the basement
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical - slight dampness allowed
#        Fa	Fair - dampness or some cracking or settling
#        Po	Poor - Severe cracking, settling, or wetness
#        NA	No Basement
#
# - BsmtExposure: Refers to walkout or garden level walls
#
#        Gd	Good Exposure
#        Av	Average Exposure (split levels or foyers typically score average or above)
#        Mn	Mimimum Exposure
#        No	No Exposure
#        NA	No Basement
#
# - BsmtFinType1: Rating of basement finished area
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement
#
# - BsmtFinType2: Rating of basement finished area (if multiple types)
#
#        GLQ	Good Living Quarters
#        ALQ	Average Living Quarters
#        BLQ	Below Average Living Quarters
#        Rec	Average Rec Room
#        LwQ	Low Quality
#        Unf	Unfinshed
#        NA	No Basement

# %%
# Check if all 79 NAs are the same observations among the variables
# with 80+ NAs

len(all_data[(all_data['BsmtQual'].isnull())&\
   (all_data['BsmtCond'].isnull())&\
   (all_data['BsmtExposure'].isnull())&\
   (all_data['BsmtFinType1'].isnull())&\
   (all_data['BsmtFinType2'].isnull())]
   )
# Out:
# 79

# %%
# The additional NAs
all_data.loc[(~all_data['BsmtFinType1'].isnull()) &\
             (all_data['BsmtCond'].isnull() |\
             all_data['BsmtQual'].isnull() |\
             all_data['BsmtExposure'].isnull() |\
             all_data['BsmtFinType2'].isnull()),
             ['BsmtQual', 'BsmtCond', 'BsmtExposure',
              'BsmtFinType1', 'BsmtFinType2']]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2
# Id
# 333        Gd       TA           No          GLQ          NaN
# 949        Gd       TA          NaN          Unf          Unf
# 1488       Gd       TA          NaN          Unf          Unf
# 2041       Gd      NaN           Mn          GLQ          Rec
# 2186       TA      NaN           No          BLQ          Unf
# 2218      NaN       Fa           No          Unf          Unf
# 2219      NaN       TA           No          Unf          Unf
# 2349       Gd       TA          NaN          Unf          Unf
# 2525       TA      NaN           Av          ALQ          Unf

# %%
all_data.loc[333,'BsmtFinType2'] = all_data['BsmtFinType2'].mode()[0]
all_data.loc[( 949,1488,2349),'BsmtExposure'] = all_data['BsmtExposure'].mode()[0]
all_data.loc[(2041,2186,2525),'BsmtCond'] = all_data['BsmtCond'].mode()[0]
all_data.loc[(2218, 2219),'BsmtQual'] = all_data['BsmtQual'].mode()[0]

# %%
# Acknowledging there is redundant code below
# I wanted extra practice typing it out for muscle memory

all_data['BsmtQual'].fillna('None', inplace=True)
all_data['BsmtQual'] = all_data['BsmtQual'].map(Qualities)

all_data['BsmtCond'].fillna('None', inplace=True)
all_data['BsmtCond'] = all_data['BsmtCond'].map(Qualities)

all_data['BsmtExposure'].fillna('None', inplace=True)
exposureQual = {'None':0, 'No':1, 'Mn':2, 'Av':3, 'Gd':4}
all_data['BsmtExposure'] = all_data['BsmtExposure'].map(exposureQual)

all_data['BsmtFinType1'].fillna('None',inplace=True)
fintypeQual = {'None':0, 'Unf':1, 'LwQ':2, 'Rec':3, 'BLQ':4, 'ALQ':5, 'GLQ':6}
all_data['BsmtFinType1'] = all_data['BsmtFinType1'].map(fintypeQual)

all_data['BsmtFinType2'].fillna('None',inplace=True)
all_data['BsmtFinType2'] = all_data['BsmtFinType2'].map(fintypeQual)

# %%
exposureQual = None
fintypeQual = None
del (exposureQual,fintypeQual)

# %%
# Remaining Basement variable NAs

all_data.loc[(all_data['BsmtFullBath'].isnull()|\
        all_data['BsmtHalfBath'].isnull()|\
        all_data['BsmtFinSF1'].isnull()|\
        all_data['BsmtFinSF2'].isnull()|\
        all_data['BsmtUnfSF'].isnull()|\
        all_data['TotalBsmtSF'].isnull()),
             ['BsmtQual', 'BsmtFullBath', 'BsmtHalfBath',
              'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF']]
# Out:
#       BsmtQual  BsmtFullBath  BsmtHalfBath  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# Id
# 2121         0           NaN           NaN         NaN         NaN        NaN
# 2189         0           NaN           NaN         0.0         0.0        0.0
#
#       TotalBsmtSF
# Id
# 2121          NaN
# 2189          0.0

# %% [markdown]
# From the look of it, those houses do not have Basments

# %%
all_data.loc[(2121,2189),['BsmtQual', 'BsmtFullBath', 'BsmtHalfBath',
              'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF']] = 0

# %% [markdown]
# **Masonry Variables:**
# - MasVnrArea: Masonry veneer area in square feet (23 NAs)
# - MasVnrType: Masonry veneer type (24 NAs)
#
#        BrkCmn	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        None	None
#        Stone	Stone

# %%
len(all_data[all_data['MasVnrType'].isnull() &\
             all_data['MasVnrArea'].isnull()])
# Out:
# 23

# %%
all_data.loc[(all_data['MasVnrType'].isnull() &\
              ~all_data['MasVnrArea'].isnull()),
            ['MasVnrType','MasVnrArea']]
# Out:
#      MasVnrType  MasVnrArea
# Id
# 2611        NaN       198.0

# %%
all_data.loc[2611,'MasVnrType'] = all_data['MasVnrType'].mode()[0]

# %%
all_data['MasVnrType'].fillna('None',inplace=True)

# %%
all_data.pivot_table(values='SalePrice',columns='MasVnrType').median().sort_values()
# Out:
# MasVnrType
# BrkCmn     146318.066667
# None       156958.243119
# BrkFace    204691.871910
# Stone      265583.625000
# dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.swarmplot(x='MasVnrType',y='SalePrice',data=all_data,order=['BrkCmn','None','BrkFace','Stone'])
plt.show()

# %%
masonryQual = {'None':0, 'BrkCmn':0, 'BrkFace':1, 'Stone':2}
all_data['MasVnrType'] = all_data['MasVnrType'].map(masonryQual)

# %%
masonryQual = None
del masonryQual

# %%
all_data['MasVnrArea'].fillna(0,inplace=True)

# %% [markdown]
# **MSZoning:**
# - MSZoning: Identifies the general zoning classification of the sale. (4 NAs)
#
#        A	Agriculture
#        C	Commercial
#        FV	Floating Village Residential
#        I	Industrial
#        RH	Residential High Density
#        RL	Residential Low Density
#        RP	Residential Low Density Park
#        RM	Residential Medium Density

# %%
all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0],inplace=True)
all_data['MSZoning'] = all_data['MSZoning'].astype('category')

# %%
all_data.pivot_table(values='SalePrice',columns='MSZoning').median().sort_values()
# Out:
# MSZoning
# C (all)     74528.000000
# RM         126316.830275
# RH         131558.375000
# RL         191004.994787
# FV         214014.061538
# dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.swarmplot(x='MSZoning',y='SalePrice',data=all_data,
              order=["C (all)","RM",'RH','RL','FV'])
plt.show()

# %% [markdown]
# **Kitchen Variables:**
# - Kitchen: Kitchens above grade (0 NA)
# - KitchenQual: Kitchen quality  (1 NA)
#
#        Ex	Excellent
#        Gd	Good
#        TA	Typical/Average
#        Fa	Fair
#        Po	Poor

# %%
all_data['KitchenQual'].fillna(all_data['KitchenQual'].mode()[0], inplace=True)
all_data['KitchenQual'] = all_data['KitchenQual'].map(Qualities)

# %%
plt.figure(figsize=(15,10))
sns.swarmplot(x='KitchenQual',y='SalePrice',data=all_data)
plt.show()

# %% [markdown]
# **Utilities:**
# - Utilities: Type of utilities available (2 NAs)
#
#        AllPub	All public Utilities (E,G,W,& S)
#        NoSewr	Electricity, Gas, and Water (Septic Tank)
#        NoSeWa	Electricity and Gas Only
#        ELO	Electricity only

# %%
all_data['Utilities'].value_counts()
# Out:
# AllPub    2916
# NoSeWa       1
# Name: Utilities, dtype: int64

# %% [markdown]
# Since all houses except for 1 have AllPub as the Utilities variable, this is not a helpful predictor.  I'm going to remove it.

# %%
all_data.drop(['Utilities'], inplace=True, axis=1)

# %% [markdown]
# **Functional:**
# - Functional: Home functionality (Assume typical unless deductions are warranted) (2 NAs)
#
#        Typ	Typical Functionality
#        Min1	Minor Deductions 1
#        Min2	Minor Deductions 2
#        Mod	Moderate Deductions
#        Maj1	Major Deductions 1
#        Maj2	Major Deductions 2
#        Sev	Severely Damaged
#        Sal	Salvage only

# %%
all_data['Functional'].fillna(all_data['Functional'].mode()[0], inplace=True)

all_data['Functional'] = \
all_data['Functional'].map({'Sal':0,'Sev':1, 'Maj2':2, 'Maj1':3,
                            'Mod':4, 'Min2':5, 'Min1':6, 'Typ':7})

all_data['Functional'].value_counts()
# Out:
# 7    2719
# 5      70
# 6      65
# 4      35
# 3      19
# 2       9
# 1       2
# Name: Functional, dtype: int64

# %% [markdown]
# **Exterior Variables:**
# - Exterior1st: Exterior covering on house (1 NAs)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# - Exterior2nd: Exterior covering on house (if more than one material) (1 NAs)
#
#        AsbShng	Asbestos Shingles
#        AsphShn	Asphalt Shingles
#        BrkComm	Brick Common
#        BrkFace	Brick Face
#        CBlock	Cinder Block
#        CemntBd	Cement Board
#        HdBoard	Hard Board
#        ImStucc	Imitation Stucco
#        MetalSd	Metal Siding
#        Other	Other
#        Plywood	Plywood
#        PreCast	PreCast
#        Stone	Stone
#        Stucco	Stucco
#        VinylSd	Vinyl Siding
#        Wd Sdng	Wood Siding
#        WdShing	Wood Shingles
#
# - ExterQual: Evaluates the quality of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor
#
# - ExterCond: Evaluates the present condition of the material on the exterior
#
#        Ex	Excellent
#        Gd	Good
#        TA	Average/Typical
#        Fa	Fair
#        Po	Poor

# %%
all_data['Exterior1st'].fillna(all_data['Exterior1st'].mode()[0],inplace=True)
all_data['Exterior1st'] = all_data['Exterior1st'].astype('category')

all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].mode()[0],inplace=True)
all_data['Exterior2nd'] = all_data['Exterior2nd'].astype('category')

all_data['ExterQual'] = all_data['ExterQual'].map(Qualities)

all_data['ExterCond'] = all_data['ExterCond'].map(Qualities)

# %% [markdown]
# **Electrical Variable:**
# - Electrical: Electrical system
#
#        SBrkr	Standard Circuit Breakers & Romex
#        FuseA	Fuse Box over 60 AMP and all Romex wiring (Average)
#        FuseF	60 AMP Fuse Box and mostly Romex wiring (Fair)
#        FuseP	60 AMP Fuse Box and mostly knob & tube wiring (poor)
#        Mix	Mixed

# %%
all_data.Electrical.fillna(all_data['Electrical'].mode()[0],inplace=True)
all_data['Electrical'] = all_data.Electrical.astype('category')

# %% [markdown]
# **Sale Type Vaeiable:**
# - SaleType: Type of sale
#
#        WD 	Warranty Deed - Conventional
#        CWD	Warranty Deed - Cash
#        VWD	Warranty Deed - VA Loan
#        New	Home just constructed and sold
#        COD	Court Officer Deed/Estate
#        Con	Contract 15% Down payment regular terms
#        ConLw	Contract Low Down payment and low interest
#        ConLI	Contract Low Interest
#        ConLD	Contract Low Down
#        Oth	Other

# %%
all_data.SaleType.fillna(all_data['SaleType'].mode()[0],inplace=True)
all_data['SaleType'] = all_data.SaleType.astype('category')

all_data['SaleCondition'] = all_data.SaleType.astype('category')

# %% [markdown]
# Double check for NA values

# %%
NAcol = all_data.isnull().sum().sort_values(ascending=False)
print("There are "+str(len(NAcol[NAcol > 0]))+" columns with missing values:")
print(NAcol[NAcol > 0])
# Out:
# There are 1 columns with missing values:
# SalePrice    1459
# dtype: int64

# %% [markdown]
# ## Label encoding/factorizing the remaining character variables

# %%
for count, i in enumerate(list(all_data.select_dtypes(include=['object']).columns)):
    print(str(count+1) +": "+ str(i))
# Out:
# 1: Street
# 2: LandContour
# 3: LandSlope
# 4: Neighborhood
# 5: Condition1
# 6: Condition2
# 7: BldgType
# 8: HouseStyle
# 9: RoofStyle
# 10: RoofMatl
# 11: Foundation
# 12: Heating
# 13: HeatingQC
# 14: CentralAir
# 15: PavedDrive

# %%
# 1
all_data['Street'] = all_data['Street'].map({'Grvl':0,'Pave':1})
# 2
all_data['LandContour'] = all_data['LandContour'].astype('category')
# 3
all_data['LandSlope'] = all_data['LandSlope'].map({'Sev':0,'Mod':1,'Gtl':2})
# 4
all_data['Neighborhood'] = all_data['Neighborhood'].astype('category')
# 5
all_data['Condition1'] = all_data['Condition1'].astype('category')
# 6
all_data['Condition2'] = all_data['Condition2'].astype('category')
# 7
all_data['BldgType'] = all_data['BldgType'].astype('category')
# 8
all_data['HouseStyle'] = all_data['HouseStyle'].astype('category')
# 9
all_data['RoofStyle'] = all_data['RoofStyle'].astype('category')
# 10
all_data['RoofMatl'] = all_data['RoofMatl'].astype('category')
# 11
all_data['Foundation'] = all_data['Foundation'].astype('category')
# 12
all_data['Heating'] = all_data['Heating'].astype('category')
# 13
all_data['HeatingQC'] = all_data['HeatingQC'].map(Qualities)
# 14
all_data['CentralAir'] = all_data['CentralAir'].map({'N':0, 'Y':1})
# 15
all_data['PavedDrive'] = all_data['PavedDrive'].map({'N':0, 'P':1, 'Y':2})

# %%
print("NA values left: "+str(all_data.isnull().sum().sum()))
print("NA values in SalePrice: "+str(all_data.SalePrice.isnull().sum()))
print("Length of test set: "+str(len(test)))
# Out:
# NA values left: 1459
# NA values in SalePrice: 1459
# Length of test set: 1459

# %% [markdown]
# ## Changing some numeric variables into factors

# %% [markdown]
# **Year and Month Sold:**

# %%
all_data['MoSold'] = all_data['MoSold'].astype('category')

# %%
median_yrSold = all_data.pivot_table(values='SalePrice',columns='YrSold')
median_moSold = all_data.pivot_table(values='SalePrice',columns='MoSold')

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(15,10))
ax1.bar(median_yrSold.median().index,median_yrSold.median().values)
ax1.axhline(median_yrSold.median().median(),color='red',linestyle='dashed')
ax1.set_xlabel('Year')
ax1.set_ylabel('SalePrice')

f.suptitle("Yearly Sale Price v Monthly Sale Price")

ax2.bar(median_moSold.median().index,median_moSold.median().values)
ax2.axhline(median_yrSold.median().median(),color='red',linestyle='dashed')
ax2.set_xlabel('Month')

plt.show()

# %%
median_yrSold = None
median_moSold = None
ax1 = None
ax2 = None
f = None
del (median_yrSold,median_moSold,ax1,ax2,f)

# %% [markdown]
# **MSSubClass:**

# %%
all_data['MSSubClass'] = all_data['MSSubClass'].astype('object')

all_data['MSSubClass'] = \
all_data['MSSubClass'].map({20:'1 story 1946+',
                            30:'1 story 1945-',
                            40:'1 story unf attic',
                            45:'1,5 story unf',
                            50:'1,5 story fin',
                            60:'2 story 1946+',
                            70:'2 story 1945-',
                            75:'2,5 story all ages',
                            80:'split/multi level',
                            85:'split foyer',
                            90:'duplex all style/age',
                            120:'1 story PUD 1946+',
                            150:'1,5 story PUD all',
                            160:'2 story PUD 1946+',
                            180:'PUD multilevel',
                            190:'2 family conversion'})

all_data['MSSubClass'] = all_data['MSSubClass'].astype('category')

# %%
column_order, NAcol, Qualities, i, count = None,None,None,None,None
del(column_order, NAcol, Qualities, i, count)
gc.collect()
# Out:
# 34040

# %% [markdown]
# # Visualization of important variables

# %%
numeric_columns = [c for c in all_data.columns if all_data[c].dtype in ['int64','float64']]
category_columns = [c for c in all_data.columns if all_data[c].dtype not in ['int64','float64']]
len(category_columns)
# Out:
# 23

# %%
high_corr_columns = all_data[numeric_columns].corr().iloc[:,55].abs().sort_values(ascending=False)

# Take only Correlations with greater than or equal to .5
# Reset the index to get column names written in column 0 instead of as the index
# Take only column 0 (column names), and make it a list
high_corr_columns = high_corr_columns[high_corr_columns >= .5].reset_index().iloc[:,0].tolist()
high_corr_columns
# Out:
# ['SalePrice',
#  'OverallQual',
#  'GrLivArea',
#  'ExterQual',
#  'KitchenQual',
#  'GarageCars',
#  'GarageArea',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'BsmtQual',
#  'FullBath',
#  'GarageFinish',
#  'TotRmsAbvGrd',
#  'YearBuilt',
#  'FireplaceQu',
#  'GarageYrBlt',
#  'YearRemodAdd']

# %%
all_data[high_corr_columns].dtypes
# Out:
# SalePrice       float64
# OverallQual       int64
# GrLivArea         int64
# ExterQual         int64
# KitchenQual       int64
# GarageCars      float64
# GarageArea      float64
# TotalBsmtSF     float64
# 1stFlrSF          int64
# BsmtQual          int64
# FullBath          int64
# GarageFinish      int64
# TotRmsAbvGrd      int64
# YearBuilt         int64
# FireplaceQu       int64
# GarageYrBlt     float64
# YearRemodAdd      int64
# dtype: object

# %%
all_data.GrLivArea
# Out:
# Id
# 1       1710
# 2       1262
# 3       1786
# 4       1717
# 5       2198
# 6       1362
# 7       1694
# 8       2090
# 9       1774
# 10      1077
# 11      1040
# 12      2324
# 13       912
# 14      1494
# 15      1253
# 16       854
# 17      1004
# 18      1296
# 19      1114
# 20      1339
# 21      2376
# 22      1108
# 23      1795
# 24      1060
# 25      1060
# 26      1600
# 27       900
# 28      1704
# 29      1600
# 30       520
#         ...
# 2890     641
# 2891    1638
# 2892     729
# 2893    1396
# 2894     936
# 2895    1778
# 2896    1646
# 2897    1625
# 2898    1664
# 2899    1491
# 2900    1210
# 2901    1650
# 2902    1403
# 2903    1960
# 2904    1838
# 2905    1600
# 2906    1368
# 2907    1304
# 2908     874
# 2909    1652
# 2910     630
# 2911    1092
# 2912    1360
# 2913    1092
# 2914    1092
# 2915    1092
# 2916    1092
# 2917    1224
# 2918     970
# 2919    2000
# Name: GrLivArea, Length: 2919, dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.heatmap(all_data[high_corr_columns].corr(), annot=True)
plt.show()

# %% [markdown]
# ## Feature Engineering
#
# ### Total Number of Bathrooms

# %%
all_data['TotBathrooms'] = all_data['FullBath'] + (all_data['HalfBath']*.5)+ all_data['BsmtFullBath'] + (all_data['BsmtHalfBath']*.5)

# %%
plt.figure(figsize=(10,5))
plt.scatter(all_data['TotBathrooms'],all_data['SalePrice'])
plt.ylabel('SalePrice')
plt.xlabel('TotBathrooms')
plt.show()

# %%
sns.jointplot(data=all_data, x='TotBathrooms',y='SalePrice', 
              kind='reg', height =8,ratio=5, color='m')

# %%
all_data[['TotBathrooms','SalePrice']].corr()
# Out:
#               TotBathrooms  SalePrice
# TotBathrooms      1.000000   0.631731
# SalePrice         0.631731   1.000000

# %% [markdown]
# ### Adding 'House age', 'Remodeled (Yes/No), and IsNew variables

# %%
all_data.loc[(all_data['YearBuilt']==all_data['YearRemodAdd']),'Remod'] = 0
all_data['Remod'].fillna(1, inplace=True)

# %%
all_data['Age'] = all_data['YrSold']-all_data['YearRemodAdd']

# %%
sns.lmplot(x='Age',y='SalePrice',hue='Remod',data=all_data, height=9, aspect=1.2)
plt.show()

# %% [markdown]
# As shown above in the figure as well as below by the correlation, there is a negative correlation between age and sale price.

# %%
all_data[['Age','SalePrice']].corr()
# Out:
#                 Age  SalePrice
# Age        1.000000  -0.509079
# SalePrice -0.509079   1.000000

# %%
all_data.loc[(all_data['YrSold']==all_data['YearBuilt']),'IsNew'] = 1
all_data['IsNew'].fillna(0,inplace=True)

# %%
del all_data['YrSold']

# %% [markdown]
# ### Binning Neighborhood

# %%
_ = all_data.pivot_table(values='SalePrice',columns='Neighborhood')

# %%
plt.figure(figsize=(10,5))
_.median().sort_values().plot(kind='bar')
plt.show()

# %%
all_data.loc[(all_data['Neighborhood'].isin(['StoneBr', 'NridgHt', 'NoRidge'])),'NeighWealth'] = 2
all_data.loc[(all_data['Neighborhood'].isin(['MeadowV', 'IDOTRR', 'BrDale'])),'NeighWealth'] = 0
all_data['NeighWealth'].fillna(1,inplace=True)

# %%
all_data.NeighWealth.value_counts()
# Out:
# 1.0    2471
# 2.0     288
# 0.0     160
# Name: NeighWealth, dtype: int64

# %% [markdown]
# ### Total Square Feet

# %%
all_data['TotalSqFeet'] = all_data['GrLivArea'] + all_data['TotalBsmtSF']

# %%
sns.jointplot(x='TotalSqFeet',y='SalePrice',data=all_data,
           kind='reg',height=9,ylim=(0,800000))
plt.show()

# %%
all_data[['SalePrice','TotalSqFeet']].corr()
# Out:
#              SalePrice  TotalSqFeet
# SalePrice     1.000000     0.778959
# TotalSqFeet   0.778959     1.000000

# %% [markdown]
# ### Consolidating Porch variables
#
# - WoodDeckSF: Wood deck area in square feet
# - OpenPorchSF: Open porch area in square feet
# - EnclosedPorch: Enclosed porch area in square feet
# - 3SsnPorch: Three season porch area in square feet
# - ScreenPorch: Screen porch area in square feet

# %%
all_data['TotalPorchSF']=all_data['OpenPorchSF']+all_data['EnclosedPorch']+all_data['3SsnPorch']+all_data['ScreenPorch']

# %%
all_data[['TotalPorchSF','SalePrice']].corr()
# Out:
#               TotalPorchSF  SalePrice
# TotalPorchSF      1.000000   0.195739
# SalePrice         0.195739   1.000000

# %%
sns.jointplot(x='TotalPorchSF',y='SalePrice',data=all_data,
              kind='reg',height=9)
plt.show()

# %% [markdown]
# TRIAL
#
# https://www.kaggle.com/ffisegydd/sklearn-multicollinearity-class

# %%
numeric_columns = [c for c in all_data.columns if all_data[c].dtype in ['int64','float64']]
len(numeric_columns)
# Out:
# 62

# %%
from scipy import interpolate

# %%
all_data.OverallQual
# Out:
# Id
# 1       7
# 2       6
# 3       7
# 4       7
# 5       8
# 6       5
# 7       8
# 8       7
# 9       7
# 10      5
# 11      5
# 12      9
# 13      5
# 14      7
# 15      6
# 16      7
# 17      6
# 18      4
# 19      5
# 20      5
# 21      8
# 22      7
# 23      8
# 24      5
# 25      5
# 26      8
# 27      5
# 28      8
# 29      5
# 30      4
#        ..
# 2890    4
# 2891    6
# 2892    3
# 2893    5
# 2894    3
# 2895    8
# 2896    8
# 2897    6
# 2898    6
# 2899    8
# 2900    6
# 2901    6
# 2902    6
# 2903    8
# 2904    9
# 2905    1
# 2906    7
# 2907    5
# 2908    5
# 2909    5
# 2910    4
# 2911    4
# 2912    5
# 2913    4
# 2914    4
# 2915    4
# 2916    4
# 2917    5
# 2918    5
# 2919    7
# Name: OverallQual, Length: 2919, dtype: int64

# %%
all_data.head()
# Out:
#        MSSubClass MSZoning  LotFrontage  LotArea  Street Alley  LotShape  \
# Id
# 1   2 story 1946+       RL         65.0     8450       1  None         3
# 2   1 story 1946+       RL         80.0     9600       1  None         3
# 3   2 story 1946+       RL         68.0    11250       1  None         2
# 4   2 story 1945-       RL         60.0     9550       1  None         2
# 5   2 story 1946+       RL         84.0    14260       1  None         2
#
#    LandContour LotConfig  LandSlope     ...      SaleType SaleCondition  \
# Id                                      ...
# 1          Lvl    Inside          2     ...            WD            WD
# 2          Lvl       FR2          2     ...            WD            WD
# 3          Lvl    Inside          2     ...            WD            WD
# 4          Lvl    Corner          2     ...            WD            WD
# 5          Lvl       FR2          2     ...            WD            WD
#
#    SalePrice TotBathrooms Remod  Age  IsNew  NeighWealth  TotalSqFeet  \
# Id
# 1   208500.0          3.5   0.0    5    0.0          1.0       2566.0
# 2   181500.0          2.5   0.0   31    0.0          1.0       2524.0
# 3   223500.0          3.5   1.0    6    0.0          1.0       2706.0
# 4   140000.0          2.0   1.0   36    0.0          1.0       2473.0
# 5   250000.0          3.5   0.0    8    0.0          2.0       3343.0
#
#    TotalPorchSF
# Id
# 1            61
# 2             0
# 3            42
# 4           307
# 5            84
#
# [5 rows x 85 columns]

# %%
all_data = all_data[all_data['OverallQual'] % 100 != 0]
all_data = all_data[all_data['SalePrice'] % 100 != 0]

# %%
x = data.OverallQual
y = data.SalePrice
plt.scatter(x, y)
plt.show()

# %%
z = np.polyfit(y, x, 5)
p = np.poly1d(z)
plt.scatter(x,p(y))
data['NewSale'] = p(data.SalePrice)
print(y.corr(x))
data['NewSale'].corr(x)
# Out:
# 0.7909816005838044
# 0.8235562904584547

# %%
price_std = data.SalePrice.std()

# %%
price_mean = data.SalePrice.mean()

# %%
all_data_new = all_data
all_data_new.SalePrice = p(all_data_new.SalePrice)

# %%
all_data = pd.get_dummies(all_data,drop_first=True)

# %%
all_data_new = pd.get_dummies(all_data, drop_first = True)

# %%
all_data_test = all_data.loc[all_data.SalePrice.isnull(),]

all_data_train = all_data.loc[all_data.SalePrice.notnull(),]

all_data_train_num = all_data_train.select_dtypes(include = ['float64', 'int64'])

all_data_test_num = all_data_test.select_dtypes(include = ['float64', 'int64'])

train_scaled = all_data_train_num.apply(lambda x: (x - x.mean())/x.std(), axis = 0)

test_scaled = all_data_test_num.apply(lambda x: (x - x.mean())/x.std(), axis = 0)

# %%
all_data_test = all_data_new.loc[all_data_new.SalePrice.isnull(),]

all_data_train = all_data_new.loc[all_data_new.SalePrice.notnull(),]

all_data_train_num = all_data_train.select_dtypes(include = ['float64', 'int64'])

all_data_test_num = all_data_test.select_dtypes(include = ['float64', 'int64'])

train_scaled = all_data_train_num.apply(lambda x: (x - x.mean())/x.std(), axis = 0)

test_scaled = all_data_test_num.apply(lambda x: (x - x.mean())/x.std(), axis = 0)

# %%
#Validation function
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train_scaled)
    rmse= np.sqrt(-cross_val_score(model, train_scaled, train_scaled.SalePrice, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %%
train_less_price = train_scaled.loc[:,train_scaled.columns [train_scaled.columns != "SalePrice"]]

# %%
test_less_price = test_scaled.loc[:,test_scaled.columns [test_scaled.columns != "SalePrice"]]

# %% [markdown]
# # SVR Default Setting Performance

# %% [markdown]
# ## Linear kaggle score = 0.22738

# %%
reg = svm.SVR(kernel = 'linear')
result = reg.fit(train_less_price, train_scaled.SalePrice)
prediction = result.predict(test_less_price)
prediction_rescaled = prediction * price_std + price_mean

# %%
rmsle_cv(reg).mean()
# Out:
# 0.1937585480176714

# %%
prediction_rescaled = pd.DataFrame(prediction_rescaled)
prediction_rescaled.index = range(1461,2920)
prediction_rescaled.index.name = "Id"
prediction_rescaled.columns = ["SalePrice"]
prediction_rescaled
prediction_rescaled.to_csv("svr_linear.csv")

# %% [markdown]
# ## Gaussian kaggle score = 0.22813

# %%
reg = svm.SVR(kernel = 'rbf')
result = reg.fit(train_less_price, train_scaled.SalePrice)
prediction = result.predict(test_less_price)
prediction_rescaled = prediction * price_std + price_mean

# %%
rmsle_cv(reg).mean()
# Out:
# 0.40834345439094893

# %%
prediction_rescaled = pd.DataFrame(prediction_rescaled)
prediction_rescaled.index = range(1461,2920)
prediction_rescaled.index.name = "Id"
prediction_rescaled.columns = ["SalePrice"]
prediction_rescaled
prediction_rescaled.to_csv("svr_rbf.csv")

# %% [markdown]
# ## Polynomial kaggle score = 0.87489

# %%
reg = svm.SVR(kernel = 'poly')
result = reg.fit(train_less_price, train_scaled.SalePrice)
prediction = result.predict(test_less_price)
prediction_rescaled = prediction * price_std + price_mean

# %%
rmsle_cv(reg).mean()
# Out:
# 0.6480196580179614

# %%
prediction_rescaled = pd.DataFrame(prediction_rescaled)
prediction_rescaled.index = range(1461,2920)
prediction_rescaled.index.name = "Id"
prediction_rescaled.columns = ["SalePrice"]
prediction_rescaled
prediction_rescaled.to_csv("svr_poly.csv")

# %% [markdown]
# ## Sigmoid kaggle score = 0.79820

# %%
reg = svm.SVR(kernel = 'sigmoid')
result = reg.fit(train_less_price, train_scaled.SalePrice)
prediction = result.predict(test_less_price)
prediction_rescaled = prediction * price_std + price_mean

# %%
rmsle_cv(reg).mean()
# Out:
# 0.3797572182273063

# %%
prediction_rescaled = pd.DataFrame(prediction_rescaled)
prediction_rescaled.index = range(1461,2920)
prediction_rescaled.index.name = "Id"
prediction_rescaled.columns = ["SalePrice"]
prediction_rescaled
prediction_rescaled.to_csv("svr_sigmoid.csv")

# %% [markdown]
# # SVR with GridSearchCV

# %% [markdown]
# # Linear SVR kaggle score = 0.22216

# %%
param_grid = {'C':[0.2, 0.4, 0.6, 0.8, 1], 'gamma' : [0.001, 0.01, 0.1, 1], 'epsilon':[0.1,0.2,0.5,0.3]}
reg = svm.SVR(kernel = 'linear', C = 0.9, cache_size = 1000)
cv = KFold(n_splits=10, shuffle=False, random_state=None)
grid = GridSearchCV(reg, param_grid=param_grid, cv=cv)
result = grid.fit(train_less_price, train_scaled.SalePrice)
prediction = result.predict(test_less_price)
prediction_rescaled = prediction * price_std + price_mean
grid_linear = grid
result.best_params_
# Out:
# {'C': 0.2, 'epsilon': 0.1, 'gamma': 0.001}

# %%
rmsle_cv(grid_linear).mean()
# Out:
# 0.1937585480176714

# %%
prediction_rescaled = pd.DataFrame(prediction_rescaled)
prediction_rescaled.index = range(1461,2920)
prediction_rescaled.index.name = "Id"
prediction_rescaled.columns = ["SalePrice"]
prediction_rescaled
prediction_rescaled.to_csv("svr_grid_linear.csv")

# %% [markdown]
# # Gaussian SVR kaggle score = 0.20548

# %%
param_grid = {'C':[0.2, 0.4, 0.6, 0.8, 1], 'gamma' : [0.001, 0.01, 0.1, 1], 'epsilon':[0.1,0.2,0.5,0.3]}
reg = svm.SVR(kernel = 'rbf', C = 0.9, cache_size = 1000)
cv = KFold(n_splits=10, shuffle=False, random_state=None)
grid = GridSearchCV(reg, param_grid=param_grid, cv=cv)
result = grid.fit(train_less_price, train_scaled.SalePrice)
prediction = result.predict(test_less_price)
prediction_rescaled = prediction * price_std + price_mean
result.best_params_
# Out:
# {'C': 0.6, 'epsilon': 0.1, 'gamma': 0.01}

# %%
grid_rbf = grid

# %%
rmsle_cv(grid_rbf).mean()
# Out:
# 0.3809191740876172

# %%
prediction_rescaled = pd.DataFrame(prediction_rescaled)
prediction_rescaled.index = range(1461,2920)
prediction_rescaled.index.name = "Id"
prediction_rescaled.columns = ["SalePrice"]
prediction_rescaled
prediction_rescaled.to_csv("svr_grid_rbf.csv")

# %% [markdown]
# # Polynomial SVR kaggle score = 0.31139

# %%
param_grid = {'C':[0.2, 0.4, 0.6, 0.8, 1], 'gamma' : [0.001, 0.01, 0.1, 1], 'epsilon':[0.1,0.2,0.5,0.3]}
reg = svm.SVR(kernel = 'poly', C = 0.9, cache_size = 1000)
cv = KFold(n_splits=10, shuffle=False, random_state=None)
grid = GridSearchCV(reg, param_grid=param_grid, cv=cv)
result = grid.fit(train_less_price, train_scaled.SalePrice)
prediction = result.predict(test_less_price)
prediction_rescaled = prediction * price_std + price_mean
result.best_params_
# Out:
# {'C': 0.8, 'epsilon': 0.5, 'gamma': 0.01}

# %%
grid_poly = grid

# %%
rmsle_cv(grid_poly).mean()
# Out:
# 0.7823629531459453

# %%
prediction_rescaled = pd.DataFrame(prediction_rescaled)
prediction_rescaled.index = range(1461,2920)
prediction_rescaled.index.name = "Id"
prediction_rescaled.columns = ["SalePrice"]
prediction_rescaled
prediction_rescaled.to_csv("svr_grid_poly.csv")

# %% [markdown]
# # Sigmoid SVR kaggle score = 0.17970

# %%
param_grid = {'C':[0.2, 0.4, 0.6, 0.8, 1], 'gamma' : [0.001, 0.01, 0.1, 1], 'epsilon':[0.1,0.2,0.5,0.3]}
reg = svm.SVR(kernel = 'sigmoid', C = 0.9, cache_size = 1000)
cv = KFold(n_splits=10, shuffle=False, random_state=None)
grid = GridSearchCV(reg, param_grid=param_grid, cv=cv)
result = grid.fit(train_less_price, train_scaled.SalePrice)
prediction = result.predict(test_less_price)
prediction_rescaled = prediction * price_std + price_mean
result.best_params_
# Out:
# {'C': 0.2, 'epsilon': 0.1, 'gamma': 0.01}

# %%
grid_sig = grid

# %%
rmsle_cv(grid_sig).mean()
# Out:
# 0.33935628593301115

# %%
prediction_rescaled = pd.DataFrame(prediction_rescaled)
prediction_rescaled.index = range(1461,2920)
prediction_rescaled.index.name = "Id"
prediction_rescaled.columns = ["SalePrice"]
prediction_rescaled
prediction_rescaled.to_csv("svr_grid_sig.csv")
